# %% [markdown]
# ## 0. 导入库

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import multiprocessing
from datetime import datetime as datetime
import spectral as sp

# %% [markdown]
# ## 1. 读取光谱数据

# %%
import spectral as sp
import numpy as np

# hdrpath = 'E:/WuJiangying/DEM/WZD_mask_L9.hdr'
# datpath = 'E:/WuJiangying/DEM/WZD_mask_L9.dat'
hdrpath = 'data/WZD_mask_L9.hdr'
datpath = 'data/WZD_mask_L9.dat'
head = sp.envi.open(hdrpath, datpath)
print(head)

data = head.load()
print(f'data shape: {data.shape}')
print(f'data type: {data.dtype}')
print(f'data max: {np.max(data)}')
print(f'data min: {np.min(data)}')
# Out:
# 	Data Source:   '.\data/WZD_mask_L9.dat'
# 	# Rows:            101
# 	# Samples:         100
# 	# Bands:             7
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:     int16
# data shape: (101, 100, 7)
# data type: float32
# data max: 0.10589999705553055
# data min: 0.0

# %% [markdown]
# ## 2. 读取深度数据

# %%
# depthhdrpath = 'E:/WuJiangying/DEM/ture_dem_9_.txt'
# depthdatpath = 'E:/WuJiangying/DEM/ture_dem_9'
depthhdrpath = 'data/ture_dem_9_.hdr'
depthdatpath = 'data/ture_dem_9'
depthhead = sp.envi.open(depthhdrpath, depthdatpath)
print(depthhead)

depthdata = depthhead.load()
print(f'depthdata shape: {depthdata.shape}')
print(f'depthdata type: {depthdata.dtype}')
print(f'depthdata max: {np.max(depthdata)}')
print(f'depthdata min: {np.min(depthdata)}')
# Out:
# 	Data Source:   '.\data/ture_dem_9'
# 	# Rows:            100
# 	# Samples:          99
# 	# Bands:             1
# 	Interleave:        BSQ
# 	Quantization:  64 bits
# 	Data format:   float64
# depthdata shape: (100, 99, 1)
# depthdata type: float32
# depthdata max: -0.18000000715255737
# depthdata min: -21.75

# %% [markdown]
# ## 3. 数据预处理
#
# - reshape
# - normalization
# - 数据随机切分

# %%
# newdata delete first row and last column
newdata = data[1:, :-1]
print(f'newdata shape: {newdata.shape}')
# Out:
# newdata shape: (100, 99, 7)

# %%
# reshaope
# newdata 100*99*7 -> 9900*7
# depthdata 100*99*1 -> 9900*1
newdata_ = newdata.reshape(-1, newdata.shape[-1])
depthdata_ = depthdata.reshape(-1, 1)
print(f'newdata_ shape: {newdata_.shape}')
print(f'depthdata_ shape: {depthdata_.shape}')
# Out:
# newdata_ shape: (9900, 7)
# depthdata_ shape: (9900, 1)

# %% [markdown]
# 归一化

# %%
# normalize the newdata to [0, 1], depthdata to [0, 1]
datamax, datamin = np.max(newdata_), np.min(newdata_)
depthmax, depthmin = np.max(depthdata_), np.min(depthdata_)
print(f'datamax: {datamax}, datamin: {datamin}')
print(f'depthmax: {depthmax}, depthmin: {depthmin}')

newdata_ = (newdata_ - datamin) / (datamax - datamin)
depthdata_ = (depthdata_ - depthmin) / (depthmax - depthmin)
print(f'newdata_ max: {np.max(newdata_)}, newdata_ min: {np.min(newdata_)}')
print(f'depthdata_ max: {np.max(depthdata_)}, depthdata_ min: {np.min(depthdata_)}')
print(f'newdata_ shape: {newdata_.shape}')
print(f'depthdata_ shape: {depthdata_.shape}')
# Out:
# datamax: 0.10589999705553055, datamin: 0.0
# depthmax: -0.18000000715255737, depthmin: -21.75
# newdata_ max: 1.0, newdata_ min: 0.0
# depthdata_ max: 1.0, depthdata_ min: 0.0
# newdata_ shape: (9900, 7)
# depthdata_ shape: (9900, 1)

# %% [markdown]
# 随机切分

# %%
import torch
import numpy as np
import random

def set_random_seed(seed):
    """Set random seeds."""
    random.seed(seed)  # Python 内置随机库
    np.random.seed(seed)  # NumPy 随机库
    torch.manual_seed(seed)  # PyTorch 随机库
    torch.cuda.manual_seed(seed)  # 当前 CUDA 设备
    torch.cuda.manual_seed_all(seed)  # 所有 CUDA 设备
    torch.backends.cudnn.deterministic = True  # 确定性卷积操作
    
    # torch.backends.cudnn.benchmark = False  # 禁止自动优化

# %%
setseed = 3407
set_random_seed(setseed)
train_num, val_num, test_num = 800, 100, 100

# TRAIN
# selcet train_num rows in train_num rows
train_index = random.sample(range(newdata_.shape[0]), train_num)
train_samples = newdata_[train_index]
train_depths = depthdata_[train_index]
print(f'train_samples shape: {train_samples.shape}')
print(f'train_depths shape: {train_depths.shape}')

# VAL
# select val_num rows in rest rows
val_index = list(set(range(newdata_.shape[0])) - set(train_index))
val_index = random.sample(val_index, val_num)
val_samples = newdata_[val_index]
val_depths = depthdata_[val_index]
print(f'val_samples shape: {val_samples.shape}')
print(f'val_depths shape: {val_depths.shape}')

# TEST
# select test_num rows in rest rows
test_index = list(set(range(newdata_.shape[0])) - set(train_index) - set(val_index))
test_index = random.sample(test_index, test_num)
test_samples = newdata_[test_index]
test_depths = depthdata_[test_index]
print(f'test_samples shape: {test_samples.shape}')
print(f'test_depths shape: {test_depths.shape}')
# Out:
# train_samples shape: (800, 7)
# train_depths shape: (800, 1)
# val_samples shape: (100, 7)
# val_depths shape: (100, 1)
# test_samples shape: (100, 7)
# test_depths shape: (100, 1)

# %% [markdown]
# ## 4. 构建模型 以及 训练

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from datetime import datetime as datetime
import joblib  # 用于保存模型
import os  # 用于创建文件夹


X_train = train_samples
y_train = train_depths  # 连续值标签
X_val = val_samples
y_val = val_depths  # 连续值标签
X_test = test_samples
y_test = test_depths  # 连续值标签

# 转换为 DMatrix 格式（XGBoost 特殊数据格式）
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)
dtest = xgb.DMatrix(X_test, label=y_test)

# 设置 XGBoost 参数
params = {
    "objective": "reg:squarederror",  # 回归任务
    "eval_metric": "rmse",           # 使用 RMSE 作为评估指标
    "max_depth": 5,                  # 决策树的最大深度
    "eta": 0.1,                      # 学习率
    "subsample": 0.8,                # 随机采样比例
    "colsample_bytree": 0.8          # 树的每列采样比例
}

# 训练模型
num_boost_round = 100  # 迭代轮数
early_stopping_rounds = 10  # 提前停止轮数
evals = [(dtrain, "train"), (dval, "val")]


# 训练模型
a = datetime.now()
print(f'开始训练时间：{a}')
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=evals,
    early_stopping_rounds=early_stopping_rounds,
    verbose_eval=True
)
b = datetime.now()
print(f'结束训练时间：{b}')
print(f'训练用时：{b-a}')
print()

# 保存训练好的模型到指定路径
if not os.path.exists('./ckpt'):
    os.makedirs('./ckpt')
model_path = './ckpt/xgboost.pkl'
joblib.dump(model, model_path)
print(f'Model saved to {model_path}')
# Out:
# 开始训练时间：2025-01-01 17:48:05.286587
# [0]	train-rmse:0.25005	val-rmse:0.22593
# [1]	train-rmse:0.22936	val-rmse:0.20702
# [2]	train-rmse:0.21063	val-rmse:0.19042
# [3]	train-rmse:0.19472	val-rmse:0.17688
# [4]	train-rmse:0.17974	val-rmse:0.16368
# [5]	train-rmse:0.16734	val-rmse:0.15360
# [6]	train-rmse:0.15658	val-rmse:0.14482
# [7]	train-rmse:0.14628	val-rmse:0.13588
# [8]	train-rmse:0.13727	val-rmse:0.12778
# [9]	train-rmse:0.12933	val-rmse:0.12180
# [10]	train-rmse:0.12334	val-rmse:0.11691
# [11]	train-rmse:0.11651	val-rmse:0.11106
# [12]	train-rmse:0.11162	val-rmse:0.10705
# [13]	train-rmse:0.10641	val-rmse:0.10269
# [14]	train-rmse:0.10193	val-rmse:0.09893
# [15]	train-rmse:0.09858	val-rmse:0.09660
# [16]	train-rmse:0.09560	val-rmse:0.09446
# [17]	train-rmse:0.09253	val-rmse:0.09183
# [18]	train-rmse:0.08965	val-rmse:0.08947
# [19]	train-rmse:0.08727	val-rmse:0.08740
# [20]	train-rmse:0.08526	val-rmse:0.08640
# [21]	train-rmse:0.08373	val-rmse:0.08586
# [22]	train-rmse:0.08201	val-rmse:0.08462
# [23]	train-rmse:0.08082	val-rmse:0.08413
# [24]	train-rmse:0.07916	val-rmse:0.08341
# [25]	train-rmse:0.07800	val-rmse:0.08264
# [26]	train-rmse:0.07733	val-rmse:0.08226
# [27]	train-rmse:0.07637	val-rmse:0.08205
# [28]	train-rmse:0.07559	val-rmse:0.08182
# [29]	train-rmse:0.07471	val-rmse:0.08156
# [30]	train-rmse:0.07430	val-rmse:0.08158
# [31]	train-rmse:0.07335	val-rmse:0.08095
# [32]	train-rmse:0.07226	val-rmse:0.08036
# [33]	train-rmse:0.07156	val-rmse:0.07951
# [34]	train-rmse:0.07110	val-rmse:0.07940
# [35]	train-rmse:0.07038	val-rmse:0.07914
# [36]	train-rmse:0.06979	val-rmse:0.07884
# [37]	train-rmse:0.06923	val-rmse:0.07897
# [38]	train-rmse:0.06852	val-rmse:0.07869
# [39]	train-rmse:0.06797	val-rmse:0.07873
# [40]	train-rmse:0.06750	val-rmse:0.07854
# [41]	train-rmse:0.06675	val-rmse:0.07811
# [42]	train-rmse:0.06640	val-rmse:0.07816
# [43]	train-rmse:0.06603	val-rmse:0.07823
# [44]	train-rmse:0.06563	val-rmse:0.07805
# [45]	train-rmse:0.06535	val-rmse:0.07792
# [46]	train-rmse:0.06480	val-rmse:0.07783
# [47]	train-rmse:0.06386	val-rmse:0.07782
# [48]	train-rmse:0.06324	val-rmse:0.07769
# [49]	train-rmse:0.06291	val-rmse:0.07768
# [50]	train-rmse:0.06273	val-rmse:0.07769
# [51]	train-rmse:0.06244	val-rmse:0.07734
# [52]	train-rmse:0.06179	val-rmse:0.07744
# [53]	train-rmse:0.06117	val-rmse:0.07752
# [54]	train-rmse:0.06064	val-rmse:0.07732
# [55]	train-rmse:0.06001	val-rmse:0.07724
# [56]	train-rmse:0.05989	val-rmse:0.07721
# [57]	train-rmse:0.05959	val-rmse:0.07690
# [58]	train-rmse:0.05916	val-rmse:0.07716
# [59]	train-rmse:0.05890	val-rmse:0.07721
# [60]	train-rmse:0.05871	val-rmse:0.07719
# [61]	train-rmse:0.05829	val-rmse:0.07711
# [62]	train-rmse:0.05786	val-rmse:0.07711
# [63]	train-rmse:0.05769	val-rmse:0.07717
# [64]	train-rmse:0.05756	val-rmse:0.07715
# [65]	train-rmse:0.05715	val-rmse:0.07700
# [66]	train-rmse:0.05681	val-rmse:0.07696
# [67]	train-rmse:0.05626	val-rmse:0.07679
# [68]	train-rmse:0.05593	val-rmse:0.07669
# [69]	train-rmse:0.05568	val-rmse:0.07666
# [70]	train-rmse:0.05529	val-rmse:0.07642
# [71]	train-rmse:0.05494	val-rmse:0.07644
# [72]	train-rmse:0.05481	val-rmse:0.07643
# [73]	train-rmse:0.05462	val-rmse:0.07638
# [74]	train-rmse:0.05425	val-rmse:0.07642
# [75]	train-rmse:0.05410	val-rmse:0.07652
# [76]	train-rmse:0.05373	val-rmse:0.07641
# [77]	train-rmse:0.05340	val-rmse:0.07639
# [78]	train-rmse:0.05313	val-rmse:0.07639
# [79]	train-rmse:0.05287	val-rmse:0.07628
# [80]	train-rmse:0.05272	val-rmse:0.07638
# [81]	train-rmse:0.05258	val-rmse:0.07647
# [82]	train-rmse:0.05234	val-rmse:0.07632
# [83]	train-rmse:0.05187	val-rmse:0.07625
# [84]	train-rmse:0.05161	val-rmse:0.07625
# [85]	train-rmse:0.05120	val-rmse:0.07620
# [86]	train-rmse:0.05110	val-rmse:0.07609
# [87]	train-rmse:0.05097	val-rmse:0.07598
# [88]	train-rmse:0.05081	val-rmse:0.07589
# [89]	train-rmse:0.05058	val-rmse:0.07611
# [90]	train-rmse:0.05050	val-rmse:0.07608
# [91]	train-rmse:0.05039	val-rmse:0.07607
# [92]	train-rmse:0.05009	val-rmse:0.07622
# [93]	train-rmse:0.04993	val-rmse:0.07618
# [94]	train-rmse:0.04967	val-rmse:0.07614
# [95]	train-rmse:0.04947	val-rmse:0.07619
# [96]	train-rmse:0.04920	val-rmse:0.07639
# [97]	train-rmse:0.04895	val-rmse:0.07637
# 结束训练时间：2025-01-01 17:48:05.396258
# 训练用时：0:00:00.109671
#
# Model saved to ./ckpt/xgboost.pkl

# %% [markdown]
# ## 4. 构建模型 以及 训练

# %% [markdown]
# ## 5. 预测 及 结果展示
#
# - 图1
#     - 画出深度图
#     - 画出预测的深度图
# - 图2
#     - 画出 实际-预测 的深度图
#     - 拟合直线
#     - 计算 NMSE，R 展示到图片上

# %%
# 对测试集进行预测
a = datetime.now()
print(f'开始测试时间：{a}')
y_pred_flat = model.predict(dtest)
b = datetime.now()
print(f'结束测试时间：{b}')
print(f'测试用时：{b-a}')
print()

# 计算均方误差
mse = mean_squared_error(test_depths, y_pred_flat)
print(f"Mean Squared Error: {mse:.6f}")

# 可以将预测结果恢复为原始的图像尺寸（1, 10, 10）
y_pred = y_pred_flat.reshape(10, 10)
y_test_reshaped = test_depths.reshape(10, 10)

# 显示一部分预测结果与真实标签
plt.subplot(1, 2, 1)
plt.imshow(y_test_reshaped, cmap='gray', vmin=0, vmax=1)
plt.title("True Label")

plt.subplot(1, 2, 2)
plt.imshow(y_pred, cmap='gray', vmin=0, vmax=1)
plt.title("Predicted Label")

plt.show()
# Out:
# 开始测试时间：2025-01-01 17:48:05.416276
# 结束测试时间：2025-01-01 17:48:05.417276
# 测试用时：0:00:00.001000
#
# Mean Squared Error: 0.009501

# %%
# 计算回归直线
y_true_ = test_depths.flatten()
y_pred_ = y_pred_flat.flatten()
coefficients = np.polyfit(y_true_, y_pred_, 1)  # 一次线性拟合
poly_eq = np.poly1d(coefficients)
y_fit = poly_eq(y_true_)

# 计算 R^2 和 RMSE
r_squared = r2_score(y_pred_, y_fit)
rmse = np.sqrt(mean_squared_error(y_pred_, y_fit))

# 绘图
plt.figure(figsize=(6, 6))
plt.scatter(y_true_, y_pred_, color='dodgerblue', alpha=0.7, label='Data points')  # 数据点
plt.plot(y_true_, y_fit, color='red', linestyle='--', label=f'Fit line ($R^2$={r_squared:.2f}, RMSE={rmse:.2f}m)')  # 拟合直线

# 图表修饰
plt.title('Bathymetry of Reference Map vs Multibeam Scan', fontsize=14)
plt.xlabel('Bathymetry of Multibeam Scan (m)', fontsize=12)
plt.ylabel('Bathymetry of Reference Map (m)', fontsize=12)
plt.legend()
plt.grid(alpha=0.4)
# plt.xlim(-25, 0)
# plt.ylim(-25, 0)
plt.xlim(0, 1)
plt.ylim(0, 1)

# 显示图表
plt.tight_layout()
plt.show()

# %%
# denormalize
y_true = y_true_ * (depthmax - depthmin) + depthmin
y_pred = y_pred_ * (depthmax - depthmin) + depthmin

# 计算回归直线
coefficients = np.polyfit(y_true, y_pred, 1)  # 一次线性拟合
poly_eq = np.poly1d(coefficients)
y_fit = poly_eq(y_true)

# 计算 R^2 和 RMSE
r_squared = r2_score(y_pred, y_fit)
rmse = np.sqrt(mean_squared_error(y_pred, y_fit))

# 绘图
plt.figure(figsize=(6, 6))
plt.scatter(y_true, y_pred, color='dodgerblue', alpha=0.7, label='Data points')  # 数据点
plt.plot(y_true, y_fit, color='red', linestyle='--', label=f'Fit line ($R^2$={r_squared:.2f}, RMSE={rmse:.2f}m)')  # 拟合直线

# 图表修饰
plt.title('Bathymetry of Reference Map vs Multibeam Scan', fontsize=14)
plt.xlabel('Bathymetry of Multibeam Scan (m)', fontsize=12)
plt.ylabel('Bathymetry of Reference Map (m)', fontsize=12)
plt.legend()
plt.grid(alpha=0.4)
plt.xlim(-25, 0)
plt.ylim(-25, 0)

# 显示图表
plt.tight_layout()
plt.show()
