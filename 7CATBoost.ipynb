# %% [markdown]
# ## 0. 导入库

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import multiprocessing
from datetime import datetime as datetime
import spectral as sp

# %% [markdown]
# ## 1. 读取光谱数据

# %%
import spectral as sp
import numpy as np

# hdrpath = 'E:/WuJiangying/DEM/WZD_mask_L9.hdr'
# datpath = 'E:/WuJiangying/DEM/WZD_mask_L9.dat'
hdrpath = 'data/WZD_mask_L9.hdr'
datpath = 'data/WZD_mask_L9.dat'
head = sp.envi.open(hdrpath, datpath)
print(head)

data = head.load()
print(f'data shape: {data.shape}')
print(f'data type: {data.dtype}')
print(f'data max: {np.max(data)}')
print(f'data min: {np.min(data)}')
# Out:
# 	Data Source:   '.\data/WZD_mask_L9.dat'
# 	# Rows:            101
# 	# Samples:         100
# 	# Bands:             7
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:     int16
# data shape: (101, 100, 7)
# data type: float32
# data max: 0.10589999705553055
# data min: 0.0

# %% [markdown]
# ## 2. 读取深度数据

# %%
# depthhdrpath = 'E:/WuJiangying/DEM/ture_dem_9_.txt'
# depthdatpath = 'E:/WuJiangying/DEM/ture_dem_9'
depthhdrpath = 'data/ture_dem_9_.hdr'
depthdatpath = 'data/ture_dem_9'
depthhead = sp.envi.open(depthhdrpath, depthdatpath)
print(depthhead)

depthdata = depthhead.load()
print(f'depthdata shape: {depthdata.shape}')
print(f'depthdata type: {depthdata.dtype}')
print(f'depthdata max: {np.max(depthdata)}')
print(f'depthdata min: {np.min(depthdata)}')
# Out:
# 	Data Source:   '.\data/ture_dem_9'
# 	# Rows:            100
# 	# Samples:          99
# 	# Bands:             1
# 	Interleave:        BSQ
# 	Quantization:  64 bits
# 	Data format:   float64
# depthdata shape: (100, 99, 1)
# depthdata type: float32
# depthdata max: -0.18000000715255737
# depthdata min: -21.75

# %% [markdown]
# ## 3. 数据预处理
#
# - reshape
# - normalization
# - 数据随机切分

# %%
# newdata delete first row and last column
newdata = data[1:, :-1]
print(f'newdata shape: {newdata.shape}')
# Out:
# newdata shape: (100, 99, 7)

# %%
# reshaope
# newdata 100*99*7 -> 9900*7
# depthdata 100*99*1 -> 9900*1
newdata_ = newdata.reshape(-1, newdata.shape[-1])
depthdata_ = depthdata.reshape(-1, 1)
print(f'newdata_ shape: {newdata_.shape}')
print(f'depthdata_ shape: {depthdata_.shape}')
# Out:
# newdata_ shape: (9900, 7)
# depthdata_ shape: (9900, 1)

# %% [markdown]
# 归一化

# %%
# normalize the newdata to [0, 1], depthdata to [0, 1]
datamax, datamin = np.max(newdata_), np.min(newdata_)
depthmax, depthmin = np.max(depthdata_), np.min(depthdata_)
print(f'datamax: {datamax}, datamin: {datamin}')
print(f'depthmax: {depthmax}, depthmin: {depthmin}')

newdata_ = (newdata_ - datamin) / (datamax - datamin)
depthdata_ = (depthdata_ - depthmin) / (depthmax - depthmin)
print(f'newdata_ max: {np.max(newdata_)}, newdata_ min: {np.min(newdata_)}')
print(f'depthdata_ max: {np.max(depthdata_)}, depthdata_ min: {np.min(depthdata_)}')
print(f'newdata_ shape: {newdata_.shape}')
print(f'depthdata_ shape: {depthdata_.shape}')
# Out:
# datamax: 0.10589999705553055, datamin: 0.0
# depthmax: -0.18000000715255737, depthmin: -21.75
# newdata_ max: 1.0, newdata_ min: 0.0
# depthdata_ max: 1.0, depthdata_ min: 0.0
# newdata_ shape: (9900, 7)
# depthdata_ shape: (9900, 1)

# %% [markdown]
# 随机切分

# %%
import torch
import numpy as np
import random

def set_random_seed(seed):
    """Set random seeds."""
    random.seed(seed)  # Python 内置随机库
    np.random.seed(seed)  # NumPy 随机库
    torch.manual_seed(seed)  # PyTorch 随机库
    torch.cuda.manual_seed(seed)  # 当前 CUDA 设备
    torch.cuda.manual_seed_all(seed)  # 所有 CUDA 设备
    torch.backends.cudnn.deterministic = True  # 确定性卷积操作
    
    # torch.backends.cudnn.benchmark = False  # 禁止自动优化

# %%
setseed = 3407
set_random_seed(setseed)
train_num, val_num, test_num = 800, 100, 100

# TRAIN
# selcet train_num rows in train_num rows
train_index = random.sample(range(newdata_.shape[0]), train_num)
train_samples = newdata_[train_index]
train_depths = depthdata_[train_index]
print(f'train_samples shape: {train_samples.shape}')
print(f'train_depths shape: {train_depths.shape}')

# VAL
# select val_num rows in rest rows
val_index = list(set(range(newdata_.shape[0])) - set(train_index))
val_index = random.sample(val_index, val_num)
val_samples = newdata_[val_index]
val_depths = depthdata_[val_index]
print(f'val_samples shape: {val_samples.shape}')
print(f'val_depths shape: {val_depths.shape}')

# TEST
# select test_num rows in rest rows
test_index = list(set(range(newdata_.shape[0])) - set(train_index) - set(val_index))
test_index = random.sample(test_index, test_num)
test_samples = newdata_[test_index]
test_depths = depthdata_[test_index]
print(f'test_samples shape: {test_samples.shape}')
print(f'test_depths shape: {test_depths.shape}')
# Out:
# train_samples shape: (800, 7)
# train_depths shape: (800, 1)
# val_samples shape: (100, 7)
# val_depths shape: (100, 1)
# test_samples shape: (100, 7)
# test_depths shape: (100, 1)

# %% [markdown]
# ## 4. 构建模型 以及 训练

# %%
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import mean_squared_error, r2_score
from datetime import datetime
import joblib  # 用于保存模型
import os  # 用于创建文件夹

# 定义训练、验证和测试数据
X_train = train_samples
y_train = train_depths  # 连续值标签
X_val = val_samples
y_val = val_depths  # 连续值标签
X_test = test_samples
y_test = test_depths  # 连续值标签

# 创建 CatBoost 数据池
train_pool = Pool(X_train, y_train)
val_pool = Pool(X_val, y_val)

# 设置 CatBoost 参数
params = {
    "iterations": 100,           # 迭代轮数
    "learning_rate": 0.1,       # 学习率
    "depth": 5,                 # 决策树的最大深度
    "loss_function": "RMSE",  # 使用 RMSE 作为损失函数
    "verbose": True,            # 输出训练日志
    "early_stopping_rounds": 10 # 提前停止轮数
}

# 创建并训练模型
a = datetime.now()
print(f'开始训练时间：{a}')
model = CatBoostRegressor(**params)
model.fit(train_pool, eval_set=val_pool)
b = datetime.now()
print(f'结束训练时间：{b}')
print(f'训练用时：{b-a}')

# 保存训练好的模型到指定路径
if not os.path.exists('./ckpt'):
    os.makedirs('./ckpt')
model_path = './ckpt/catboost.pkl'
joblib.dump(model, model_path)
print(f'Model saved to {model_path}')
# Out:
# 开始训练时间：2025-01-01 17:48:11.609561
# 0:	learn: 0.2559194	test: 0.2316180	best: 0.2316180 (0)	total: 984us	remaining: 97.5ms
# 1:	learn: 0.2377491	test: 0.2148221	best: 0.2148221 (1)	total: 1.7ms	remaining: 83.5ms
# 2:	learn: 0.2229079	test: 0.2011317	best: 0.2011317 (2)	total: 2.36ms	remaining: 76.2ms
# 3:	learn: 0.2094626	test: 0.1889526	best: 0.1889526 (3)	total: 2.91ms	remaining: 70ms
# 4:	learn: 0.1983041	test: 0.1798751	best: 0.1798751 (4)	total: 3.52ms	remaining: 67ms
# 5:	learn: 0.1888346	test: 0.1715952	best: 0.1715952 (5)	total: 4.15ms	remaining: 65ms
# 6:	learn: 0.1787341	test: 0.1622008	best: 0.1622008 (6)	total: 4.87ms	remaining: 64.7ms
# 7:	learn: 0.1694649	test: 0.1528406	best: 0.1528406 (7)	total: 5.6ms	remaining: 64.5ms
# 8:	learn: 0.1617932	test: 0.1462924	best: 0.1462924 (8)	total: 6.24ms	remaining: 63.1ms
# 9:	learn: 0.1557615	test: 0.1419184	best: 0.1419184 (9)	total: 6.97ms	remaining: 62.7ms
# 10:	learn: 0.1486679	test: 0.1371029	best: 0.1371029 (10)	total: 7.76ms	remaining: 62.8ms
# 11:	learn: 0.1426408	test: 0.1319356	best: 0.1319356 (11)	total: 8.48ms	remaining: 62.2ms
# 12:	learn: 0.1377883	test: 0.1271143	best: 0.1271143 (12)	total: 9.14ms	remaining: 61.2ms
# 13:	learn: 0.1327725	test: 0.1223109	best: 0.1223109 (13)	total: 9.83ms	remaining: 60.4ms
# 14:	learn: 0.1291703	test: 0.1185730	best: 0.1185730 (14)	total: 10.6ms	remaining: 59.9ms
# 15:	learn: 0.1251535	test: 0.1146123	best: 0.1146123 (15)	total: 11.2ms	remaining: 59ms
# 16:	learn: 0.1226870	test: 0.1125497	best: 0.1125497 (16)	total: 11.9ms	remaining: 58.3ms
# 17:	learn: 0.1198301	test: 0.1096530	best: 0.1096530 (17)	total: 12.6ms	remaining: 57.3ms
# 18:	learn: 0.1173795	test: 0.1076340	best: 0.1076340 (18)	total: 13.2ms	remaining: 56.2ms
# 19:	learn: 0.1152285	test: 0.1059735	best: 0.1059735 (19)	total: 13.9ms	remaining: 55.4ms
# 20:	learn: 0.1132708	test: 0.1043220	best: 0.1043220 (20)	total: 14.6ms	remaining: 54.9ms
# 21:	learn: 0.1122126	test: 0.1039345	best: 0.1039345 (21)	total: 15.2ms	remaining: 53.9ms
# 22:	learn: 0.1106849	test: 0.1025944	best: 0.1025944 (22)	total: 16ms	remaining: 53.5ms
# 23:	learn: 0.1089816	test: 0.1012443	best: 0.1012443 (23)	total: 16.6ms	remaining: 52.6ms
# 24:	learn: 0.1076396	test: 0.0996507	best: 0.0996507 (24)	total: 17.3ms	remaining: 52ms
# 25:	learn: 0.1065531	test: 0.0987751	best: 0.0987751 (25)	total: 18.1ms	remaining: 51.4ms
# 26:	learn: 0.1053665	test: 0.0976545	best: 0.0976545 (26)	total: 18.7ms	remaining: 50.5ms
# 27:	learn: 0.1044121	test: 0.0966707	best: 0.0966707 (27)	total: 19.3ms	remaining: 49.6ms
# 28:	learn: 0.1037202	test: 0.0959710	best: 0.0959710 (28)	total: 19.9ms	remaining: 48.7ms
# 29:	learn: 0.1025671	test: 0.0949695	best: 0.0949695 (29)	total: 20.4ms	remaining: 47.5ms
# 30:	learn: 0.1016003	test: 0.0938474	best: 0.0938474 (30)	total: 20.9ms	remaining: 46.5ms
# 31:	learn: 0.1005959	test: 0.0928483	best: 0.0928483 (31)	total: 21.4ms	remaining: 45.4ms
# 32:	learn: 0.0999058	test: 0.0920790	best: 0.0920790 (32)	total: 21.9ms	remaining: 44.4ms
# 33:	learn: 0.0992740	test: 0.0916066	best: 0.0916066 (33)	total: 22.4ms	remaining: 43.5ms
# 34:	learn: 0.0987188	test: 0.0909809	best: 0.0909809 (34)	total: 23ms	remaining: 42.7ms
# 35:	learn: 0.0981194	test: 0.0903550	best: 0.0903550 (35)	total: 23.6ms	remaining: 41.9ms
# 36:	learn: 0.0973729	test: 0.0901062	best: 0.0901062 (36)	total: 24.3ms	remaining: 41.3ms
# 37:	learn: 0.0971710	test: 0.0901926	best: 0.0901062 (36)	total: 24.8ms	remaining: 40.5ms
# 38:	learn: 0.0968720	test: 0.0899433	best: 0.0899433 (38)	total: 25.3ms	remaining: 39.6ms
# 39:	learn: 0.0963573	test: 0.0900650	best: 0.0899433 (38)	total: 25.9ms	remaining: 38.8ms
# 40:	learn: 0.0961282	test: 0.0901445	best: 0.0899433 (38)	total: 26.4ms	remaining: 38ms
# 41:	learn: 0.0957595	test: 0.0896304	best: 0.0896304 (41)	total: 27ms	remaining: 37.3ms
# 42:	learn: 0.0956183	test: 0.0896319	best: 0.0896304 (41)	total: 27.5ms	remaining: 36.5ms
# 43:	learn: 0.0950934	test: 0.0893339	best: 0.0893339 (43)	total: 28.1ms	remaining: 35.7ms
# 44:	learn: 0.0945456	test: 0.0887229	best: 0.0887229 (44)	total: 28.6ms	remaining: 35ms
# 45:	learn: 0.0943759	test: 0.0886827	best: 0.0886827 (45)	total: 29.1ms	remaining: 34.1ms
# 46:	learn: 0.0941088	test: 0.0886717	best: 0.0886717 (46)	total: 29.5ms	remaining: 33.3ms
# 47:	learn: 0.0939854	test: 0.0887131	best: 0.0886717 (46)	total: 30ms	remaining: 32.5ms
# 48:	learn: 0.0938555	test: 0.0887320	best: 0.0886717 (46)	total: 30.5ms	remaining: 31.7ms
# 49:	learn: 0.0934043	test: 0.0884117	best: 0.0884117 (49)	total: 30.9ms	remaining: 30.9ms
# 50:	learn: 0.0930412	test: 0.0876315	best: 0.0876315 (50)	total: 31.4ms	remaining: 30.1ms
# 51:	learn: 0.0928605	test: 0.0874752	best: 0.0874752 (51)	total: 31.8ms	remaining: 29.4ms
# 52:	learn: 0.0923162	test: 0.0869360	best: 0.0869360 (52)	total: 32.3ms	remaining: 28.7ms
# 53:	learn: 0.0920422	test: 0.0868900	best: 0.0868900 (53)	total: 32.8ms	remaining: 27.9ms
# 54:	learn: 0.0917282	test: 0.0867862	best: 0.0867862 (54)	total: 33.2ms	remaining: 27.2ms
# 55:	learn: 0.0915034	test: 0.0864796	best: 0.0864796 (55)	total: 33.7ms	remaining: 26.5ms
# 56:	learn: 0.0913046	test: 0.0864460	best: 0.0864460 (56)	total: 34.3ms	remaining: 25.9ms
# 57:	learn: 0.0908172	test: 0.0856293	best: 0.0856293 (57)	total: 34.8ms	remaining: 25.2ms
# 58:	learn: 0.0905803	test: 0.0856554	best: 0.0856293 (57)	total: 35.4ms	remaining: 24.6ms
# 59:	learn: 0.0904121	test: 0.0854400	best: 0.0854400 (59)	total: 35.8ms	remaining: 23.9ms
# 60:	learn: 0.0901470	test: 0.0851501	best: 0.0851501 (60)	total: 36.3ms	remaining: 23.2ms
# 61:	learn: 0.0898062	test: 0.0851086	best: 0.0851086 (61)	total: 36.8ms	remaining: 22.5ms
# 62:	learn: 0.0891825	test: 0.0846061	best: 0.0846061 (62)	total: 37.3ms	remaining: 21.9ms
# 63:	learn: 0.0889477	test: 0.0846292	best: 0.0846061 (62)	total: 37.8ms	remaining: 21.3ms
# 64:	learn: 0.0887211	test: 0.0846972	best: 0.0846061 (62)	total: 38.4ms	remaining: 20.7ms
# 65:	learn: 0.0884945	test: 0.0845079	best: 0.0845079 (65)	total: 39ms	remaining: 20.1ms
# 66:	learn: 0.0881506	test: 0.0839831	best: 0.0839831 (66)	total: 39.5ms	remaining: 19.5ms
# 67:	learn: 0.0879378	test: 0.0836359	best: 0.0836359 (67)	total: 40ms	remaining: 18.8ms
# 68:	learn: 0.0874880	test: 0.0834020	best: 0.0834020 (68)	total: 40.5ms	remaining: 18.2ms
# 69:	learn: 0.0874280	test: 0.0834135	best: 0.0834020 (68)	total: 41ms	remaining: 17.6ms
# 70:	learn: 0.0873586	test: 0.0834230	best: 0.0834020 (68)	total: 41.5ms	remaining: 17ms
# 71:	learn: 0.0870437	test: 0.0834248	best: 0.0834020 (68)	total: 42.1ms	remaining: 16.4ms
# 72:	learn: 0.0869271	test: 0.0834819	best: 0.0834020 (68)	total: 42.6ms	remaining: 15.7ms
# 73:	learn: 0.0868709	test: 0.0835127	best: 0.0834020 (68)	total: 43ms	remaining: 15.1ms
# 74:	learn: 0.0866400	test: 0.0832868	best: 0.0832868 (74)	total: 43.5ms	remaining: 14.5ms
# 75:	learn: 0.0865231	test: 0.0832896	best: 0.0832868 (74)	total: 43.9ms	remaining: 13.9ms
# 76:	learn: 0.0862583	test: 0.0832590	best: 0.0832590 (76)	total: 44.4ms	remaining: 13.3ms
# 77:	learn: 0.0861252	test: 0.0832602	best: 0.0832590 (76)	total: 44.9ms	remaining: 12.7ms
# 78:	learn: 0.0856789	test: 0.0831602	best: 0.0831602 (78)	total: 45.4ms	remaining: 12.1ms
# 79:	learn: 0.0855378	test: 0.0832563	best: 0.0831602 (78)	total: 45.8ms	remaining: 11.5ms
# 80:	learn: 0.0853646	test: 0.0832042	best: 0.0831602 (78)	total: 46.3ms	remaining: 10.9ms
# 81:	learn: 0.0849306	test: 0.0827940	best: 0.0827940 (81)	total: 46.8ms	remaining: 10.3ms
# 82:	learn: 0.0847655	test: 0.0827775	best: 0.0827775 (82)	total: 47.2ms	remaining: 9.66ms
# 83:	learn: 0.0847079	test: 0.0827696	best: 0.0827696 (83)	total: 47.6ms	remaining: 9.07ms
# 84:	learn: 0.0842669	test: 0.0826821	best: 0.0826821 (84)	total: 48.1ms	remaining: 8.48ms
# 85:	learn: 0.0841006	test: 0.0824881	best: 0.0824881 (85)	total: 48.6ms	remaining: 7.91ms
# 86:	learn: 0.0836136	test: 0.0822968	best: 0.0822968 (86)	total: 49.1ms	remaining: 7.34ms
# 87:	learn: 0.0834611	test: 0.0821146	best: 0.0821146 (87)	total: 49.6ms	remaining: 6.76ms
# 88:	learn: 0.0834156	test: 0.0821166	best: 0.0821146 (87)	total: 50.1ms	remaining: 6.19ms
# 89:	learn: 0.0831395	test: 0.0820909	best: 0.0820909 (89)	total: 50.6ms	remaining: 5.62ms
# 90:	learn: 0.0828810	test: 0.0819521	best: 0.0819521 (90)	total: 51ms	remaining: 5.05ms
# 91:	learn: 0.0828366	test: 0.0819526	best: 0.0819521 (90)	total: 51.5ms	remaining: 4.48ms
# 92:	learn: 0.0823414	test: 0.0818371	best: 0.0818371 (92)	total: 52ms	remaining: 3.92ms
# 93:	learn: 0.0819724	test: 0.0817265	best: 0.0817265 (93)	total: 52.6ms	remaining: 3.36ms
# 94:	learn: 0.0819290	test: 0.0817278	best: 0.0817265 (93)	total: 53.1ms	remaining: 2.79ms
# 95:	learn: 0.0814583	test: 0.0809695	best: 0.0809695 (95)	total: 53.6ms	remaining: 2.23ms
# 96:	learn: 0.0814181	test: 0.0809701	best: 0.0809695 (95)	total: 54.1ms	remaining: 1.67ms
# 97:	learn: 0.0812385	test: 0.0808039	best: 0.0808039 (97)	total: 54.6ms	remaining: 1.11ms
# 98:	learn: 0.0812018	test: 0.0808041	best: 0.0808039 (97)	total: 55.1ms	remaining: 556us
# 99:	learn: 0.0808592	test: 0.0807320	best: 0.0807320 (99)	total: 55.7ms	remaining: 0us
#
# bestTest = 0.08073200256
# bestIteration = 99
#
# 结束训练时间：2025-01-01 17:48:11.715191
# 训练用时：0:00:00.105630
# Model saved to ./ckpt/catboost.pkl

# %% [markdown]
# ## 4. 构建模型 以及 训练

# %% [markdown]
# ## 5. 预测 及 结果展示
#
# - 图1
#     - 画出深度图
#     - 画出预测的深度图
# - 图2
#     - 画出 实际-预测 的深度图
#     - 拟合直线
#     - 计算 NMSE，R 展示到图片上

# %%
# 对测试集进行预测
a = datetime.now()
print(f'开始测试时间：{a}')
y_pred_flat = model.predict(X_test)
b = datetime.now()
print(f'结束测试时间：{b}')
print(f'测试用时：{b-a}')
print()

# 计算均方误差
mse = mean_squared_error(test_depths, y_pred_flat)
print(f"Mean Squared Error: {mse:.6f}")

# 可以将预测结果恢复为原始的图像尺寸（1, 10, 10）
y_pred = y_pred_flat.reshape(10, 10)
y_test_reshaped = test_depths.reshape(10, 10)

# 显示一部分预测结果与真实标签
plt.subplot(1, 2, 1)
plt.imshow(y_test_reshaped, cmap='gray', vmin=0, vmax=1)
plt.title("True Label")

plt.subplot(1, 2, 2)
plt.imshow(y_pred, cmap='gray', vmin=0, vmax=1)
plt.title("Predicted Label")

plt.show()
# Out:
# 开始测试时间：2025-01-01 17:48:11.731684
# 结束测试时间：2025-01-01 17:48:11.732684
# 测试用时：0:00:00.001000
#
# Mean Squared Error: 0.009252

# %%
# 计算回归直线
y_true_ = test_depths.flatten()
y_pred_ = y_pred_flat.flatten()
coefficients = np.polyfit(y_true_, y_pred_, 1)  # 一次线性拟合
poly_eq = np.poly1d(coefficients)
y_fit = poly_eq(y_true_)

# 计算 R^2 和 RMSE
r_squared = r2_score(y_pred_, y_fit)
rmse = np.sqrt(mean_squared_error(y_pred_, y_fit))

# 绘图
plt.figure(figsize=(6, 6))
plt.scatter(y_true_, y_pred_, color='dodgerblue', alpha=0.7, label='Data points')  # 数据点
plt.plot(y_true_, y_fit, color='red', linestyle='--', label=f'Fit line ($R^2$={r_squared:.2f}, RMSE={rmse:.2f}m)')  # 拟合直线

# 图表修饰
plt.title('Bathymetry of Reference Map vs Multibeam Scan', fontsize=14)
plt.xlabel('Bathymetry of Multibeam Scan (m)', fontsize=12)
plt.ylabel('Bathymetry of Reference Map (m)', fontsize=12)
plt.legend()
plt.grid(alpha=0.4)
# plt.xlim(-25, 0)
# plt.ylim(-25, 0)
plt.xlim(0, 1)
plt.ylim(0, 1)

# 显示图表
plt.tight_layout()
plt.show()

# %%
# denormalize
y_true = y_true_ * (depthmax - depthmin) + depthmin
y_pred = y_pred_ * (depthmax - depthmin) + depthmin

# 计算回归直线
coefficients = np.polyfit(y_true, y_pred, 1)  # 一次线性拟合
poly_eq = np.poly1d(coefficients)
y_fit = poly_eq(y_true)

# 计算 R^2 和 RMSE
r_squared = r2_score(y_pred, y_fit)
rmse = np.sqrt(mean_squared_error(y_pred, y_fit))

# 绘图
plt.figure(figsize=(6, 6))
plt.scatter(y_true, y_pred, color='dodgerblue', alpha=0.7, label='Data points')  # 数据点
plt.plot(y_true, y_fit, color='red', linestyle='--', label=f'Fit line ($R^2$={r_squared:.2f}, RMSE={rmse:.2f}m)')  # 拟合直线

# 图表修饰
plt.title('Bathymetry of Reference Map vs Multibeam Scan', fontsize=14)
plt.xlabel('Bathymetry of Multibeam Scan (m)', fontsize=12)
plt.ylabel('Bathymetry of Reference Map (m)', fontsize=12)
plt.legend()
plt.grid(alpha=0.4)
plt.xlim(-25, 0)
plt.ylim(-25, 0)

# 显示图表
plt.tight_layout()
plt.show()
